# %%
import model1_free_text_chunked_pipeline_v3 as m1fc3

# %%
train_df, test_df = m1fc3.prepare_train_test_data(
    "free-text.csv",
    "synthetic_free_text.csv",
    chunk_size=50,
    test_size=0.2,
    random_state=42
)
# Out:
# Real raw shape: (562583, 9)
# Synthetic raw shape: (562372, 9)
#
# Real train chunks shape: (8889, 19)
# Real test chunks shape: (2264, 19)
# Synthetic train chunks shape: (8886, 19)
# Synthetic test chunks shape: (2263, 19)
#
# Final train shape: (17775, 19)
# Final test shape: (4527, 19)
#
# Train class counts:
# label
# 0    8889
# 1    8886
# Name: count, dtype: int64
#
# Test class counts:
# label
# 0    2264
# 1    2263
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = m1fc3.preprocess_train_test(train_df, test_df)
# Out:
# Dropping columns: ['participant', 'session', 'chunk_id']
#
# X_train shape: (17775, 15)
# X_test shape: (4527, 15)

# %%
print(X_train.shape, X_test.shape)
print(y_train.value_counts())
print(y_test.value_counts())
print(X_train.columns)
# Out:
# (17775, 15) (4527, 15)
# label
# 0    8889
# 1    8886
# Name: count, dtype: int64
# label
# 0    2264
# 1    2263
# Name: count, dtype: int64
# Index(['DU_hold_mean', 'DU_hold_std', 'DD_mean', 'DD_std', 'DU_flight_mean',
#        'DU_flight_std', 'UD_mean', 'UD_std', 'UU_mean', 'UU_std',
#        'total_events', 'total_time', 'avg_time_per_event', 'overall_mean',
#        'overall_std'],
#       dtype='object')

# %%
X_train_mi, X_test_mi, mi_features, mi_scores = m1fc3.select_mutual_info(
    X_train, y_train, X_test, k=10
)
X_train_mi_scaled, X_test_mi_scaled = m1fc3.scale_data(X_train_mi, X_test_mi)
mi_results = m1fc3.evaluate_models(X_train_mi_scaled, X_test_mi_scaled, y_train, y_test)
# Out:
# Top Mutual Information Features:
#            Feature     Score
# 1      DU_hold_std  0.618509
# 3           DD_std  0.593801
# 7           UD_std  0.574504
# 5    DU_flight_std  0.559546
# 0     DU_hold_mean  0.516740
# 4   DU_flight_mean  0.369332
# 14     overall_std  0.360801
# 9           UU_std  0.332452
# 11      total_time  0.185707
# 2          DD_mean  0.185093
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.990943229511818
#
# Confusion Matrix:
# [[2261    3]
#  [  38 2225]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2264
#            1       1.00      0.98      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.996963949165325
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9918268168765186
#
# Confusion Matrix:
# [[2260    4]
#  [  33 2230]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2264
#            1       1.00      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9967908230264401
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9940357852882704
#
# Confusion Matrix:
# [[2238   26]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2264
#            1       0.99      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9995376146301932
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.9898387453059422
#
# Confusion Matrix:
# [[2244   20]
#  [  26 2237]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9991169981371862
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9944775789706207
#
# Confusion Matrix:
# [[2244   20]
#  [   5 2258]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2264
#            1       0.99      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9951655452829276
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 4        Decision Tree  0.994478  0.995166
# 2        Random Forest  0.994036  0.999538
# 1           Linear SVM  0.991827  0.996791
# 0  Logistic Regression  0.990943  0.996964
# 3          Naive Bayes  0.989839  0.999117

# %%
X_train_anova, X_test_anova, anova_features, anova_scores = m1fc3.select_anova(
    X_train, y_train, X_test, k=10
)
X_train_anova_scaled, X_test_anova_scaled = m1fc3.scale_data(X_train_anova, X_test_anova)
anova_results = m1fc3.evaluate_models(X_train_anova_scaled, X_test_anova_scaled, y_train, y_test)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:110: UserWarning: Features [10] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:111: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw
# Top ANOVA Features:
#            Feature        Score        P_Value
# 0     DU_hold_mean  6764.315047   0.000000e+00
# 4   DU_flight_mean  5024.976533   0.000000e+00
# 13    overall_mean  3877.844734   0.000000e+00
# 14     overall_std  1287.997884  2.220687e-272
# 3           DD_std   822.024907  9.083639e-177
# 1      DU_hold_std   669.342339  6.617977e-145
# 5    DU_flight_std   454.136928   1.592692e-99
# 7           UD_std   308.615405   1.658702e-68
# 8          UU_mean   241.507206   4.188975e-54
# 6          UD_mean    12.847370   3.388587e-04
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.9962447537000221
#
# Confusion Matrix:
# [[2259    5]
#  [  12 2251]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2264
#            1       1.00      0.99      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9960709930374795
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9966865473823724
#
# Confusion Matrix:
# [[2262    2]
#  [  13 2250]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2264
#            1       1.00      0.99      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9976872924242969
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9887342611000662
#
# Confusion Matrix:
# [[2214   50]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      2264
#            1       0.98      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9990667388578592
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.9757013474707311
#
# Confusion Matrix:
# [[2218   46]
#  [  64 2199]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      2264
#            1       0.98      0.97      0.98      2263
#
#     accuracy                           0.98      4527
#    macro avg       0.98      0.98      0.98      4527
# weighted avg       0.98      0.98      0.98      4527
#
# ROC-AUC: 0.9964514021070252
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9891760547824167
#
# Confusion Matrix:
# [[2236   28]
#  [  21 2242]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9937507709675858
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 1           Linear SVM  0.996687  0.997687
# 0  Logistic Regression  0.996245  0.996071
# 4        Decision Tree  0.989176  0.993751
# 2        Random Forest  0.988734  0.999067
# 3          Naive Bayes  0.975701  0.996451

# %%
X_train_corr, X_test_corr, corr_features, corr_scores = m1fc3.select_correlation(
    X_train, y_train, X_test, k=10
)
X_train_corr_scaled, X_test_corr_scaled = m1fc3.scale_data(X_train_corr, X_test_corr)
corr_results = m1fc3.evaluate_models(X_train_corr_scaled, X_test_corr_scaled, y_train, y_test)
# Out:
# Top Correlation Features:
#           Feature     Score
# 0    DU_hold_mean  0.525047
# 1  DU_flight_mean  0.469482
# 2    overall_mean  0.423212
# 3     overall_std  0.259947
# 4          DD_std  0.210254
# 5     DU_hold_std  0.190509
# 6   DU_flight_std  0.157846
# 7          UD_std  0.130644
# 8         UU_mean  0.115785
# 9         UD_mean  0.026876
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.9962447537000221
#
# Confusion Matrix:
# [[2259    5]
#  [  12 2251]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2264
#            1       1.00      0.99      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9960709930374795
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9966865473823724
#
# Confusion Matrix:
# [[2262    2]
#  [  13 2250]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2264
#            1       1.00      0.99      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9976872924242969
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9887342611000662
#
# Confusion Matrix:
# [[2214   50]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      2264
#            1       0.98      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9990667388578592
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.9757013474707311
#
# Confusion Matrix:
# [[2218   46]
#  [  64 2199]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      2264
#            1       0.98      0.97      0.98      2263
#
#     accuracy                           0.98      4527
#    macro avg       0.98      0.98      0.98      4527
# weighted avg       0.98      0.98      0.98      4527
#
# ROC-AUC: 0.9964514021070252
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9891760547824167
#
# Confusion Matrix:
# [[2236   28]
#  [  21 2242]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9937507709675858
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 1           Linear SVM  0.996687  0.997687
# 0  Logistic Regression  0.996245  0.996071
# 4        Decision Tree  0.989176  0.993751
# 2        Random Forest  0.988734  0.999067
# 3          Naive Bayes  0.975701  0.996451

# %%
X_train_var, X_test_var, var_features, var_scores = m1fc3.select_variance(
    X_train, X_test, threshold=0.0, k=10
)
X_train_var_scaled, X_test_var_scaled = m1fc3.scale_data(X_train_var, X_test_var)
var_results = m1fc3.evaluate_models(X_train_var_scaled, X_test_var_scaled, y_train, y_test)
# Out:
# Top Variance Features:
#           Feature      Score
# 0      total_time  98.624628
# 1          DD_std   2.669429
# 2   DU_flight_std   1.445753
# 3          UD_std   1.367972
# 4     DU_hold_std   1.083384
# 5  DU_flight_mean   0.080176
# 6    DU_hold_mean   0.057281
# 7         UD_mean   0.055465
# 8          UU_std   0.041723
# 9         DD_mean   0.039450
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.9991164126352993
#
# Confusion Matrix:
# [[2263    1]
#  [   3 2260]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2264
#            1       1.00      1.00      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9995581087052585
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9991164126352993
#
# Confusion Matrix:
# [[2263    1]
#  [   3 2260]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2264
#            1       1.00      1.00      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9994296791681827
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9931521979235697
#
# Confusion Matrix:
# [[2237   27]
#  [   4 2259]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2264
#            1       0.99      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9997639277734144
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.9913850231941683
#
# Confusion Matrix:
# [[2244   20]
#  [  19 2244]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9993151075294842
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9940357852882704
#
# Confusion Matrix:
# [[2244   20]
#  [   7 2256]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2264
#            1       0.99      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9947193599915057
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 0  Logistic Regression  0.999116  0.999558
# 1           Linear SVM  0.999116  0.999430
# 4        Decision Tree  0.994036  0.994719
# 2        Random Forest  0.993152  0.999764
# 3          Naive Bayes  0.991385  0.999315

# %%
X_train_md, X_test_md, md_features, md_scores = m1fc3.select_mean_difference(
    X_train, y_train, X_test, k=10
)
X_train_md_scaled, X_test_md_scaled = m1fc3.scale_data(X_train_md, X_test_md)
md_results = m1fc3.evaluate_models(X_train_md_scaled, X_test_md_scaled, y_train, y_test)
# Out:
# Top Mean Difference Features:
#           Feature     Score
# 0          DD_std  0.687023
# 1      total_time  0.440639
# 2     DU_hold_std  0.396575
# 3   DU_flight_std  0.379576
# 4          UD_std  0.305595
# 5  DU_flight_mean  0.265864
# 6    DU_hold_mean  0.251317
# 7    overall_mean  0.110523
# 8     overall_std  0.086597
# 9         UU_mean  0.018660
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.9984537221117739
#
# Confusion Matrix:
# [[2263    1]
#  [   6 2257]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2264
#            1       1.00      1.00      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9999970722749907
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9997791031588248
#
# Confusion Matrix:
# [[2264    0]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2264
#            1       1.00      1.00      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 1.0
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9880715705765407
#
# Confusion Matrix:
# [[2211   53]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      2264
#            1       0.98      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9993780536171848
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.980561077976585
#
# Confusion Matrix:
# [[2218   46]
#  [  42 2221]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2264
#            1       0.98      0.98      0.98      2263
#
#     accuracy                           0.98      4527
#    macro avg       0.98      0.98      0.98      4527
# weighted avg       0.98      0.98      0.98      4527
#
# ROC-AUC: 0.9978530016598249
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9889551579412414
#
# Confusion Matrix:
# [[2236   28]
#  [  22 2241]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.993524653006032
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 1           Linear SVM  0.999779  1.000000
# 0  Logistic Regression  0.998454  0.999997
# 4        Decision Tree  0.988955  0.993525
# 2        Random Forest  0.988072  0.999378
# 3          Naive Bayes  0.980561  0.997853

# %%
X_train_rfe_lr, X_test_rfe_lr, rfe_lr_features = m1fc3.select_rfe_lr(
    X_train, y_train, X_test, k=10
)
X_train_rfe_lr_scaled, X_test_rfe_lr_scaled = m1fc3.scale_data(X_train_rfe_lr, X_test_rfe_lr)
rfe_lr_results = m1fc3.evaluate_models(X_train_rfe_lr_scaled, X_test_rfe_lr_scaled, y_train, y_test)
# Out:
# RFE Logistic Regression Features:
# ['DU_hold_mean', 'DU_hold_std', 'DD_std', 'DU_flight_mean', 'DU_flight_std', 'UD_mean', 'UD_std', 'UU_mean', 'overall_mean', 'overall_std']
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.9962447537000221
#
# Confusion Matrix:
# [[2259    5]
#  [  12 2251]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2264
#            1       1.00      0.99      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9960709930374795
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9966865473823724
#
# Confusion Matrix:
# [[2262    2]
#  [  13 2250]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2264
#            1       1.00      0.99      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9976872924242969
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9878506737353656
#
# Confusion Matrix:
# [[2210   54]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      2264
#            1       0.98      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9990282880694035
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.9757013474707311
#
# Confusion Matrix:
# [[2218   46]
#  [  64 2199]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      2264
#            1       0.98      0.97      0.98      2263
#
#     accuracy                           0.98      4527
#    macro avg       0.98      0.98      0.98      4527
# weighted avg       0.98      0.98      0.98      4527
#
# ROC-AUC: 0.9964514021070252
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9887342611000662
#
# Confusion Matrix:
# [[2236   28]
#  [  23 2240]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9932985350444781
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 1           Linear SVM  0.996687  0.997687
# 0  Logistic Regression  0.996245  0.996071
# 4        Decision Tree  0.988734  0.993299
# 2        Random Forest  0.987851  0.999028
# 3          Naive Bayes  0.975701  0.996451

# %%
X_train_rfe_lr, X_test_rfe_lr, rfe_lr_features = m1fc3.select_rfe_lr(
    X_train, y_train, X_test, k=10
)
X_train_rfe_lr_scaled, X_test_rfe_lr_scaled = m1fc3.scale_data(X_train_rfe_lr, X_test_rfe_lr)
rfe_lr_results = m1fc3.evaluate_models(X_train_rfe_lr_scaled, X_test_rfe_lr_scaled, y_train, y_test)
# Out:
# RFE Logistic Regression Features:
# ['DU_hold_mean', 'DU_hold_std', 'DD_std', 'DU_flight_mean', 'DU_flight_std', 'UD_mean', 'UD_std', 'UU_mean', 'overall_mean', 'overall_std']
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.9962447537000221
#
# Confusion Matrix:
# [[2259    5]
#  [  12 2251]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2264
#            1       1.00      0.99      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9960709930374795
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9966865473823724
#
# Confusion Matrix:
# [[2262    2]
#  [  13 2250]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2264
#            1       1.00      0.99      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9976872924242969
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9878506737353656
#
# Confusion Matrix:
# [[2210   54]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      2264
#            1       0.98      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9990282880694035
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.9757013474707311
#
# Confusion Matrix:
# [[2218   46]
#  [  64 2199]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      2264
#            1       0.98      0.97      0.98      2263
#
#     accuracy                           0.98      4527
#    macro avg       0.98      0.98      0.98      4527
# weighted avg       0.98      0.98      0.98      4527
#
# ROC-AUC: 0.9964514021070252
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9887342611000662
#
# Confusion Matrix:
# [[2236   28]
#  [  23 2240]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9932985350444781
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 1           Linear SVM  0.996687  0.997687
# 0  Logistic Regression  0.996245  0.996071
# 4        Decision Tree  0.988734  0.993299
# 2        Random Forest  0.987851  0.999028
# 3          Naive Bayes  0.975701  0.996451

# %%
X_train_rfe_rf, X_test_rfe_rf, rfe_rf_features = m1fc3.select_rfe_rf(
    X_train, y_train, X_test, k=10
)
X_train_rfe_rf_scaled, X_test_rfe_rf_scaled = m1fc3.scale_data(X_train_rfe_rf, X_test_rfe_rf)
rfe_rf_results = m1fc3.evaluate_models(X_train_rfe_rf_scaled, X_test_rfe_rf_scaled, y_train, y_test)
# Out:
# RFE Random Forest Features:
# ['DU_hold_mean', 'DU_hold_std', 'DD_std', 'DU_flight_mean', 'DU_flight_std', 'UD_mean', 'UD_std', 'UU_std', 'avg_time_per_event', 'overall_std']
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.9991164126352993
#
# Confusion Matrix:
# [[2263    1]
#  [   3 2260]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2264
#            1       1.00      1.00      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9995620123386043
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9988955157941242
#
# Confusion Matrix:
# [[2262    2]
#  [   3 2260]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2264
#            1       1.00      1.00      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9993754186646763
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9933730947647449
#
# Confusion Matrix:
# [[2237   27]
#  [   3 2260]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2264
#            1       0.99      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9991601332856569
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.9889551579412414
#
# Confusion Matrix:
# [[2241   23]
#  [  27 2236]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9986288487872973
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9942566821294455
#
# Confusion Matrix:
# [[2244   20]
#  [   6 2257]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2264
#            1       0.99      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9949424526372167
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 0  Logistic Regression  0.999116  0.999562
# 1           Linear SVM  0.998896  0.999375
# 4        Decision Tree  0.994257  0.994942
# 2        Random Forest  0.993373  0.999160
# 3          Naive Bayes  0.988955  0.998629

# %%
X_train_sfm_lr, X_test_sfm_lr, sfm_lr_features, sfm_lr_scores = m1fc3.select_sfm_lr(
    X_train, y_train, X_test, k=10
)
X_train_sfm_lr_scaled, X_test_sfm_lr_scaled = m1fc3.scale_data(X_train_sfm_lr, X_test_sfm_lr)
sfm_lr_results = m1fc3.evaluate_models(X_train_sfm_lr_scaled, X_test_sfm_lr_scaled, y_train, y_test)
# Out:
# SelectFromModel Logistic Regression Features:
#           Feature      Score
# 0    DU_hold_mean  50.858073
# 6         UD_mean  47.302170
# 13   overall_mean  42.561634
# 8         UU_mean  10.024718
# 5   DU_flight_std   6.014461
# 3          DD_std   4.189592
# 1     DU_hold_std   3.627083
# 11     total_time   1.195384
# 7          UD_std   1.117016
# 10   total_events   0.188049
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.9995582063176497
#
# Confusion Matrix:
# [[2263    1]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2264
#            1       1.00      1.00      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9999882890999627
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9995582063176497
#
# Confusion Matrix:
# [[2263    1]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2264
#            1       1.00      1.00      1.00      2263
#
#     accuracy                           1.00      4527
#    macro avg       1.00      1.00      1.00      4527
# weighted avg       1.00      1.00      1.00      4527
#
# ROC-AUC: 0.9999937541866467
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9878506737353656
#
# Confusion Matrix:
# [[2210   54]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      2264
#            1       0.98      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9990579556828314
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.9840954274353877
#
# Confusion Matrix:
# [[2218   46]
#  [  26 2237]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      2264
#            1       0.98      0.99      0.98      2263
#
#     accuracy                           0.98      4527
#    macro avg       0.98      0.98      0.98      4527
# weighted avg       0.98      0.98      0.98      4527
#
# ROC-AUC: 0.9980823401188891
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9887342611000662
#
# Confusion Matrix:
# [[2235   29]
#  [  22 2241]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9930844207554624
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 0  Logistic Regression  0.999558  0.999988
# 1           Linear SVM  0.999558  0.999994
# 4        Decision Tree  0.988734  0.993084
# 2        Random Forest  0.987851  0.999058
# 3          Naive Bayes  0.984095  0.998082

# %%
X_train_sfm_rf, X_test_sfm_rf, sfm_rf_features, sfm_rf_scores = m1fc3.select_sfm_rf(
    X_train, y_train, X_test, k=10
)
X_train_sfm_rf_scaled, X_test_sfm_rf_scaled = m1fc3.scale_data(X_train_sfm_rf, X_test_sfm_rf)
sfm_rf_results = m1fc3.evaluate_models(X_train_sfm_rf_scaled, X_test_sfm_rf_scaled, y_train, y_test)
# Out:
# SelectFromModel Random Forest Features:
#                Feature     Score
# 5        DU_flight_std  0.190660
# 1          DU_hold_std  0.173736
# 3               DD_std  0.167121
# 0         DU_hold_mean  0.123324
# 7               UD_std  0.092622
# 4       DU_flight_mean  0.084288
# 9               UU_std  0.079402
# 14         overall_std  0.047125
# 8              UU_mean  0.010645
# 12  avg_time_per_event  0.008433
#
# ============================================================
# Model: Logistic Regression
# Accuracy: 0.9922686105588691
#
# Confusion Matrix:
# [[2261    3]
#  [  32 2231]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2264
#            1       1.00      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9981367958040627
#
# ============================================================
# Model: Linear SVM
# Accuracy: 0.9931521979235697
#
# Confusion Matrix:
# [[2263    1]
#  [  30 2233]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2264
#            1       1.00      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9983450546430596
#
# ============================================================
# Model: Random Forest
# Accuracy: 0.9938148884470952
#
# Confusion Matrix:
# [[2237   27]
#  [   1 2262]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2264
#            1       0.99      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9996959069623643
#
# ============================================================
# Model: Naive Bayes
# Accuracy: 0.9898387453059422
#
# Confusion Matrix:
# [[2242   22]
#  [  24 2239]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2264
#            1       0.99      0.99      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9986784249307886
#
# ============================================================
# Model: Decision Tree
# Accuracy: 0.9940357852882704
#
# Confusion Matrix:
# [[2244   20]
#  [   7 2256]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2264
#            1       0.99      1.00      0.99      2263
#
#     accuracy                           0.99      4527
#    macro avg       0.99      0.99      0.99      4527
# weighted avg       0.99      0.99      0.99      4527
#
# ROC-AUC: 0.9947193599915057
#
# Results Table:
#                  Model  Accuracy   ROC_AUC
# 4        Decision Tree  0.994036  0.994719
# 2        Random Forest  0.993815  0.999696
# 1           Linear SVM  0.993152  0.998345
# 0  Logistic Regression  0.992269  0.998137
# 3          Naive Bayes  0.989839  0.998678
